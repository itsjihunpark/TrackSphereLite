# %%
import os
import glob

# %%
ROOT_DIR_PUTTING = "../data/Processing/Golf_Ball_Putting_data" 
ROOT_DIR_FLIGHTED = "../data/Processing/Golf_Ball_Flighted_data"  

TOP_DIRS_PUTTING = [os.path.join(ROOT_DIR_PUTTING, dir) for dir in os.listdir(ROOT_DIR_PUTTING)]
TOP_DIRS_FLIGHTED = [os.path.join(ROOT_DIR_FLIGHTED, dir) for dir in os.listdir(ROOT_DIR_FLIGHTED)]

TOP_DIRS = TOP_DIRS_PUTTING + TOP_DIRS_FLIGHTED
TOP_DIRS
# Out:
# ['../data/Processing/Golf_Ball_Putting_data\\KP_Study_Room',
#  '../data/Processing/Golf_Ball_Putting_data\\PR_Library_Bottom_Floor',
#  '../data/Processing/Golf_Ball_Putting_data\\PR_Library_Top_Floor',
#  '../data/Processing/Golf_Ball_Flighted_data\\KP_Common_Area',
#  '../data/Processing/Golf_Ball_Flighted_data\\KP_Study_Area']
